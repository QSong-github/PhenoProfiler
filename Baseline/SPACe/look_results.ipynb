# %%
import pandas as pd
import numpy as np

# %%
path = "/data/boom/cpg0001/2020_08_11_Stain3_Yokogawa/images/BR00115125/Step4_Features/texture_features.csv"

csv1 = pd.read_csv(path)
print(csv1.shape)
csv1.head()
# Out:
# (739389, 300)
#    Texture_W1-img-Nucleus-Mask_Contrast_25%  \
# 0                                      2.75
# 1                                      2.40
# 2                                      2.03
# 3                                      3.04
# 4                                      2.45
#
#    Texture_W1-img-Nucleus-Mask_Contrast_50%  \
# 0                                      5.52
# 1                                      5.02
# 2                                      4.61
# 3                                      6.12
# 4                                      4.97
#
#    Texture_W1-img-Nucleus-Mask_Contrast_75%  \
# 0                                      7.85
# 1                                      6.89
# 2                                      6.95
# 3                                      8.71
# 4                                      7.43
#
#    Texture_W1-img-Nucleus-Mask_Contrast_mean  \
# 0                                       5.31
# ...

# %%
path = "/data/boom/cpg0001/2020_08_11_Stain3_Yokogawa/images/BR00115125/Step4_Features/intensity_features.csv"

csv2 = pd.read_csv(path)
print(csv2.shape)
csv2.head()
# Out:
# (739389, 80)
#    Intensity_W1-img-Nucleus-Mask_10  Intensity_W1-img-Nucleus-Mask_25  \
# 0                           10183.8                          13558.50
# 1                            8723.0                          11843.00
# 2                            6909.5                           9610.25
# 3                            5949.2                           8161.50
# 4                           13155.3                          19096.00
#
#    Intensity_W1-img-Nucleus-Mask_75  Intensity_W1-img-Nucleus-Mask_90  \
# 0                          17893.50                           19649.0
# 1                          15222.00                           16613.0
# 2                          14138.50                           16031.7
# 3                          11019.00                           11852.0
# 4                          24770.75                           27268.3
#
#    Intensity_W1-img-Nucleus-Mask_median  Intensity_W1-img-Nucleus-Mask_mad  \
# ...

# %%
path = "/data/boom/cpg0001/2020_08_11_Stain3_Yokogawa/images/BR00115125/Step4_Features/shape_features.csv"

csv3 = pd.read_csv(path)
print(csv3.shape)
csv3.head()
# Out:
# (739389, 25)
#    Shape_Area_cell  Shape_Area_nucleus  Shape_Area_cyto  Shape_Area_nucleoli  \
# 0           2876.0              1803.0           1092.0                440.0
# 1           3107.0              1951.0           1175.0                630.0
# 2           3192.0              1902.0           1290.0                505.0
# 3           1434.0               604.0            830.0                198.0
# 4           3263.0              2194.0           1090.0                573.0
#
#    Shape_Area_mito  Shape_Nucleus_convex-area  Shape_Nucleus_perimeter  \
# 0            396.0                     1918.0                   169.30
# 1            436.0                     2029.0                   172.95
# 2            235.0                     1937.0                   164.85
# 3            395.0                      675.0                   103.74
# 4            568.0                     2269.0                   180.85
#
# ...

# %%
path = "/data/boom/cpg0001/2020_08_11_Stain3_Yokogawa/images/BR00115125/Step4_Features/bbox_features.csv"

csv4 = pd.read_csv(path)
print(csv4.shape)
csv4.head()
# Out:
# (739389, 8)
#    Nucleus_BBox-y0  Nucleus_BBox-x0  Nucleus_BBox-y1  Nucleus_BBox-x1  \
# 0              0.0           1106.0             66.0           1167.0
# 1              4.0           1300.0             62.0           1374.0
# 2              7.0           1641.0             76.0           1706.0
# 3              9.0            658.0             57.0            706.0
# 4             16.0            470.0             78.0            546.0
#
#    Cell_BBox-y0  Cell_BBox-x0  Cell_BBox-y1  Cell_BBox-x1
# 0           0.0        1106.0          66.0        1167.0
# 1           4.0        1300.0          62.0        1374.0
# 2           7.0        1641.0          76.0        1706.0
# 3           9.0         658.0          57.0         706.0
# 4          16.0         470.0          78.0         546.0

# %%
path = "/data/boom/cpg0001/2020_08_11_Stain3_Yokogawa/images/BR00115125/Step4_Features/misc_features.csv"

csv5 = pd.read_csv(path)
print(csv5.shape)
csv5.head()
# Out:
# (739389, 9)
#    Misc_Count_# nucleoli  Misc_Area-Ratio_nucleus/cell  \
# 0                    6.0                          0.63
# 1                    5.0                          0.63
# 2                    5.0                          0.60
# 3                    4.0                          0.42
# 4                    5.0                          0.67
#
#    Misc_Area-Ratio_cyto/cell  Misc_Area-Ratio_nucleoli/cell  \
# 0                       0.38                           0.15
# 1                       0.38                           0.20
# 2                       0.40                           0.16
# 3                       0.58                           0.14
# 4                       0.33                           0.18
#
#    Misc_Area-Ratio_mito/cell  Misc_Area-Ratio_nucleus/cyto  \
# 0                       0.14                          1.65
# 1                       0.14                          1.66
# 2                       0.07                          1.47
# ...

# %%
path = "/data/boom/cpg0001/2020_08_11_Stain3_Yokogawa/images/BR00115125/Step4_Features/metadata_features.csv"

csv6 = pd.read_csv(path)
print(csv6.shape)
csv6.head()
# Out:
# (739389, 8)
#    exp-id well-id  fov treatment cell-line  density  dosage  other
# 0  images     A01    1     az191      u2os     3000       2      0
# 1  images     A01    1     az191      u2os     3000       2      0
# 2  images     A01    1     az191      u2os     3000       2      0
# 3  images     A01    1     az191      u2os     3000       2      0
# 4  images     A01    1     az191      u2os     3000       2      0
